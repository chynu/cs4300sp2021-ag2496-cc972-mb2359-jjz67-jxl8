# %% [markdown]
# # Topic Modeling on Pitchfork Reviews

# %%
from pprint import pprint
import numpy as np

import json
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import stopwords
import gensim
import gensim.corpora as corpora
import gensim.models.ldamodel as lda
import spacy
import itertools

import pandas as pd
import sqlite3

import re
import unidecode as ud
import pickle
import datetime

from singernlp.ArtistReviewAnalyzer import ArtistReviewAnalyzer
# Out:
# /Users/celinechoo/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# Initializing analyzer

# %%
pf_file = "../data/processed/artist_reviews_pf_only.json"
more_sw = ['band', 'make', 'record', 'get', 'even', 'time', 'year', 'good', 'new', 'come', \
                     'go', 'well', 'first', 'take', 'still', 'way', 'much', 'feel', 'work', \
                     'release', 'seem', 'know', 'back', 'thing', 'also', 'album', 'song', 'None']
pf = ArtistReviewAnalyzer()

# %%
t0 = datetime.datetime.now()
pf.build(pf_file, more_stopwords=more_sw, min_df=300, max_df=0.6)
t1 = datetime.datetime.now()
print((t1 - t0).total_seconds())
# Out:
# 135.882591

# %%
print("tf matrix shape:", pf.count_matrix.shape)
print("tfidf matrix shape:", pf.tfidf_matrix.shape)
# Out:
# tf matrix shape: (1235019, 615)
# tfidf matrix shape: (1235019, 615)

# %% [markdown]
# ## Finding the Optimal Topic Count
#
# Source: https://stackoverflow.com/questions/32313062/what-is-the-best-way-to-obtain-the-optimal-number-of-topics-for-a-lda-model-usin

# %%
num_topics = list(range(16)[1:])
num_keywords = 15
id2word = corpora.Dictionary(pf.tokenized_reviews)
corpus = [id2word.doc2bow(w) for w in pf.tokenized_reviews]

LDA_models = {}
LDA_topics = {}
for i in num_topics:
    LDA_models[i] = lda.LdaModel(corpus=corpus,
                                 id2word=id2word,
                                 num_topics=i,
                                 update_every=1,
                                 chunksize=len(corpus),
                                 passes=20,
                                 alpha='auto',
                                 random_state=42)

    shown_topics = LDA_models[i].show_topics(num_topics=i, 
                                             num_words=num_keywords,
                                             formatted=False)
    LDA_topics[i] = [[word[0] for word in topic[1]] for topic in shown_topics]

# %%
for i in LDA_topics:
    print(LDA_topics[i])
    print()
    print()
# Out:
# [['song', 'make', 'rock', 'pop', 'sound', '-', 'love', 'album', 'year', 'get', 'track', 'guitar', 'record', 'go', 'rap']]
#
#
# [['song', 'rock', 'make', 'band', '-', 'guitar', 'sound', 'album', 'love', 'pop', 'record', 'live', 'year', 'set', 'play'], ['rap', 'song', 'make', 'pop', 'sound', '-', 'beat', 'track', 'get', 'love', 'year', 'album', 'come', 'go', 'say']]
#
#
# [['song', 'make', 'love', 'rock', '-', 'pop', 'album', 'sound', 'record', 'year', 'guitar', 'get', 'give', 'go', 'live'], ['rap', 'make', 'song', 'beat', 'sound', '-', 'pop', 'get', 'track', 'rapper', 'love', 'year', 'come', 'album', 'say'], ['song', 'rock', 'band', 'make', 'guitar', 'pop', '-', 'sound', 'album', 'live', 'record', 'year', 'love', 'track', 'set']]
#
#
# [['love', 'song', 'rock', 'make', '-', 'pop', 'album', 'sound', 'get', 'guitar', 'death', 'give', 'record', 'year', 'end'], ['rap', 'make', 'beat', 'song', 'sound', 'rapper', 'get', '-', 'pop', 'track', 'hop', 'year', 'hip', 'love', 'come'], ['song', 'pop', 'make', 'rock', 'love', 'album', '-', 'band', 'year', 'live', 'record', 'single', 'guitar', 'sound', 'track'], ['song', 'rock', 'make', 'guitar', 'sound', '-', 'band', 'album', 'record', 'live', 'year', 'pop', 'love', 'go', 'track']]
#
#
# [['love', 'rock', 'song', 'make', 'death', 'pop', 'corgan', '-', 'give', 'record', 'pumpkin', 'get', 'grip', 'band', 'live'], ['rap', 'make', 'song', 'beat', 'rapper', 'pop', 'sound', 'get', '-', 'track', 'come', 'love', 'hop', 'say', 'year'], ['song', 'pop', 'make', 'rock', 'love', '-', 'sound', 'album', 'band', 'guitar', 'year', 'vocal', 'track', 'good', 'live'], ['song', 'rock', 'guitar', 'make', 'sound', '-', 'album', 'record', 'band', 'year', 'go', 'pop', 'live', 'get', 'love'], ['song', 'rock', 'make', 'album', '-', 'band', 'pop', 'love', 'sound', 'year', 'guitar', 'live', 'record', 'track', 'single']]
#
#
# [['song', 'rock', 'beatle', 'make', 'love', 'record', 'live', 'year', 'album', '-', 'play', 'pop', 'never', 'set', 'mile'], ['rap', 'make', 'beat', 'song', 'rapper', 'pop', 'get', 'sound', 'track', '-', 'hop', 'come', 'say', 'hip', 'year'], ['song', 'young', 'bowie', 'pop', 'make', 'live', 'love', 'year', 'rock', '-', 'album', 'record', 'hit', 'set', 'sound'], ['song', 'rock', 'guitar', 'make', 'sound', '-', 'band', 'album', 'pop', 'record', 'vocal', 'go', 'love', 'live', 'year'], ['song', 'rock', 'make', '-', 'band', 'album', 'love', 'sound', 'guitar', 'pop', 'year', 'track', 'record', 'live', 'give'], ['song', 'pop', 'death', 'love', 'grip', 'make', 'sound', 'smith', 'get', 'record', 'bear', 'voice', 'moment', 'seem', 'want']]
#
#
# [['beatle', 'song', 'love', 'rock', 'make', 'pop', 'mccartney', 'corgan', 'lennon', 'record', 'album', 'guitar', 'never', 'give', 'pumpkin'], ['rap', 'make', 'beat', 'rapper', 'song', 'get', 'sound', '-', 'track', 'pop', 'hop', 'hip', 'come', 'say', 'year'], ['song', 'pop', 'make', 'love', 'sound', '-', 'rock', 'prince', 'year', 'live', 'album', 'track', 'good', 'band', 'come'], ['song', 'rock', 'make', 'guitar', '-', 'sound', 'record', 'band', 'live', 'album', 'year', 'young', 'set', 'love', 'go'], ['song', 'rock', 'make', 'band', 'pop', '-', 'album', 'sound', 'guitar', 'love', 'year', 'track', 'single', 'record', 'get'], ['reznor', 'death', 'grip', 'sound', 'song', 'pop', 'bundick', 'love', 'bear', 'ferry', 'grizzly', 'get', 'make', '-', 'want'], ['song', 'make', 'love', 'album', 'year', 'record', '-', 'sound', 'voice', 'live', 'go', 'pop', 'guitar', 'say', 'old']]
#
#
# [['beatle', 'song', 'rock', 'love', 'make', 'smith', 'morrissey', 'album', 'pop', '-', 'record', 'mccartney', 'give', 'guitar', 'single'], ['rap', 'make', 'song', 'beat', 'rapper', 'pop', 'sound', 'get', '-', 'track', 'hop', 'say', 'hip', 'come', 'year'], ['song', 'pop', 'make', 'love', '-', 'rock', 'sound', 'year', 'album', 'live', 'good', 'track', 'band', 'record', 'go'], ['song', 'rock', 'guitar', 'make', '-', 'sound', 'band', 'album', 'record', 'year', 'young', 'live', 'love', 'go', 'never'], ['song', 'rock', 'make', 'band', 'pop', '-', 'album', 'love', 'sound', 'guitar', 'track', 'year', 'live', 'single', 'record'], ['reznor', 'death', 'grip', 'bear', 'ferry', 'sound', 'grizzly', 'love', 'song', 'make', 'shield', 'matsson', 'voice', 'record', 'ride'], ['song', 'set', 'record', 'make', 'live', 'year', 'love', 'mile', 'play', 'album', 'sound', '-', 'hear', 'disc', 'take'], ['make', 'pop', 'song', 'sound', 'beat', 'track', 'rap', '-', 'come', 'love', 'get', 'vocal', 'year', 'production', 'voice']]
#
#
# [['rock', 'weezer', 'song', 'love', 'make', '-', 'underworld', 'pop', 'cuomo', 'lennon', 'give', 'sound', 'pinkerton', 'scream', 'point'], ['rap', 'rapper', 'make', 'beat', 'hop', 'hip', 'get', 'sound', 'song', 'track', '-', 'say', 'year', 'come', 'mixtape'], ['bowie', 'song', 'rock', 'make', 'prince', 'guitar', '-', 'pop', 'album', 'corgan', 'year', 'mogwai', 'young', 'love', 'sound'], ['song', 'rock', 'make', 'guitar', 'sound', 'album', 'love', 'record', 'young', 'live', 'year', 'go', '-', 'voice', 'pop'], ['song', 'rock', 'band', 'make', 'album', '-', 'guitar', 'pop', 'sound', 'love', 'live', 'year', 'record', 'track', 'never'], ['reznor', 'death', 'grip', 'ferry', 'bear', 'grizzly', '-', 'sound', 'pusha', 'makonnen', 'ride', 'machine', 'song', 'trent', 'pop'], ['song', 'make', 'love', 'record', '-', 'rock', 'album', 'year', 'cash', 'live', 'sound', 'track', 'guitar', 'band', 'come'], ['pop', 'make', 'song', 'sound', 'track', 'beat', 'love', 'come', '-', 'year', 'beam', 'wu', 'voice', 'vocal', 'single'], ['pop', 'song', 'make', 'love', '-', 'single', 'sound', 'get', 'year', 'album', 'play', 'come', 'rock', 'vocal', 'track']]
#
#
# [['mccartney', 'underworld', 'lennon', 'rock', 'song', 'coltrane', 'make', 'love', 'scream', 'veloso', '-', 'bronson', 'give', 'point', 'primal'], ['rap', 'make', 'beat', 'rapper', 'song', 'get', 'sound', 'hop', 'hip', '-', 'track', 'pop', 'say', 'come', 'year'], ['song', 'prince', 'pop', 'love', 'make', 'banhart', 'sound', 'year', 'come', '-', 'live', 'album', 'buckley', 'track', 'record'], ['rock', 'song', 'guitar', 'make', 'sound', '-', 'band', 'record', 'young', 'album', 'live', 'set', 'year', 'go', 'pop'], ['song', 'rock', 'band', 'make', 'album', 'pop', '-', 'guitar', 'sound', 'love', 'year', 'live', 'track', 'record', 'single'], ['death', 'wilco', 'grip', 'meloy', 'love', 'decemberist', 'ferry', 'song', 'tweedy', 'sound', 'ride', 'dead', 'voice', 'foxtrot', '-'], ['song', 'beatle', 'love', 'make', 'pop', 'album', 'cash', 'record', 'year', 'cohen', 'say', 'sound', 'get', 'track', '-'], ['make', 'pop', 'sound', 'beat', 'track', 'song', 'rap', '-', 'love', 'year', 'come', 'voice', 'production', 'single', 'beam'], ['song', 'pop', 'make', 'love', '-', 'get', 'rock', 'sound', 'single', 'year', 'record', 'album', 'guitar', 'play', 'vocal'], ['bowie', 'adam', 'rock', 'song', 'root', 'make', 'year', 'play', 'album', 'never', 'live', 'get', '-', 'man', 'love']]
#
#
# [['rock', 'weezer', 'make', 'vile', 'underworld', 'song', '-', 'cuomo', 'love', 'pinkerton', 'pop', 'scream', 'bronson', 'give', 'veloso'], ['rap', 'make', 'beat', 'rapper', 'song', 'sound', 'get', 'track', '-', 'hop', 'pop', 'hip', 'say', 'come', 'love'], ['song', 'banhart', 'pop', 'love', 'reed', 'madonna', 'make', 'pixie', 'etten', 'van', 'come', 'year', 'sound', 'go', 'track'], ['song', 'rock', 'guitar', 'make', 'sound', '-', 'album', 'band', 'vocal', 'pop', 'go', 'year', 'track', 'never', 'love'], ['song', 'rock', 'band', 'make', 'album', 'guitar', '-', 'love', 'pop', 'sound', 'record', 'live', 'year', 'track', 'give'], ['death', 'grip', 'ferry', 'bear', 'grizzly', 'love', 'ride', 'sound', 'apple', 'moment', 'money', 'watson', '-', 'yellow', 'pop'], ['song', 'prince', 'make', 'love', 'cash', 'album', 'track', 'sound', '-', 'record', 'live', 'big', 'old', 'year', 'death'], ['young', 'song', 'make', 'sound', 'record', 'track', 'year', 'pop', 'love', 'come', '-', 'soul', 'voice', 'beatle', 'album'], ['pop', 'song', 'make', 'love', '-', 'get', 'single', 'rock', 'year', 'sound', 'album', 'play', 'record', 'track', 'go'], ['bowie', 'root', 'snoop', 'year', 'album', 'make', 'never', 'rock', 'get', 'hit', '-', 'man', 'song', 'david', 'live'], ['mile', 'play', 'set', 'davis', 'make', '-', 'live', 'rock', 'record', 'song', 'band', 'year', 'sound', 'jazz', 'never']]
#
#
# [['vile', 'song', 'rock', 'veloso', 'bronson', 'scream', 'haggard', 'primal', 'make', 'lennon', 'point', '-', 'love', 'pop', 'man'], ['rap', 'make', 'rapper', 'beat', 'song', 'get', 'hop', 'sound', 'hip', 'track', '-', 'pop', 'say', 'come', 'year'], ['song', 'pop', 'prince', 'love', 'banhart', 'make', '-', 'sound', 'rock', 'live', 'buckley', 'guitar', 'track', 'single', 'come'], ['rock', 'song', 'make', 'guitar', '-', 'band', 'sound', 'album', 'go', 'pop', 'record', 'track', 'vocal', 'year', 'give'], ['song', 'rock', 'make', 'band', 'album', 'love', 'guitar', 'sound', 'pop', '-', 'live', 'record', 'track', 'year', 'never'], ['death', 'grip', 'ferry', 'grizzly', 'bear', 'ride', 'simpson', 'love', 'watson', 'sound', 'money', 'droste', 'mc', 'voice', 'hill'], ['song', 'make', 'love', 'sound', 'album', 'band', 'year', 'cash', 'guitar', 'cohen', 'rock', 'pop', 'long', '-', 'voice'], ['song', 'make', 'darnielle', 'sound', 'track', 'love', 'come', '-', 'guitar', 'pop', 'year', 'voice', 'record', 'beat', 'album'], ['song', 'pop', 'make', 'rock', '-', 'love', 'year', 'single', 'record', 'sound', 'album', 'get', 'live', 'set', 'track'], ['bowie', 'song', 'oberst', 'make', 'year', 'sound', 'rock', 'album', 'never', 'find', '-', 'harvey', 'live', 'play', 'guitar'], ['make', 'song', '-', 'play', 'sound', 'rock', 'band', 'blur', 'record', 'pop', 'guitar', 'year', 'interpol', 'give', 'live'], ['mile', 'davis', 'jazz', 'set', 'play', 'blue', 'record', 'live', 'solo', 'disc', 'coltrane', 'take', 'brew', 'key', 'kind']]
#
#
# [['coltrane', 'veloso', 'bronson', 'love', 'jazz', 'grande', 'swinscoe', 'brazilian', 'year', 'piece', 'brazil', 'never', 'man', 'take', 'soul'], ['rap', 'make', 'rapper', 'beat', 'song', 'get', 'sound', 'hop', 'hip', 'track', 'say', '-', 'pop', 'come', 'year'], ['prince', 'song', 'pop', 'make', 'sound', 'rock', 'love', 'year', 'guitar', 'madonna', '-', 'track', 'album', 'record', 'etten'], ['song', 'rock', 'make', 'guitar', '-', 'young', 'album', 'band', 'sound', 'live', 'record', 'love', 'go', 'year', 'long'], ['song', 'rock', 'band', 'make', 'pop', 'guitar', 'album', '-', 'sound', 'love', 'year', 'record', 'live', 'track', 'single'], ['death', 'grip', 'ferry', 'love', 'ride', 'money', 'mc', 'store', 'hill', 'roxy', 'plate', 'voice', 'government', 'deep', 'web'], ['song', 'cash', 'keef', 'make', 'beat', 'buckley', 'love', 'life', 'record', 'track', 'voice', 'year', 'go', 'big', 'live'], ['rap', 'beat', 'make', 'track', 'sound', 'rapper', 'come', 'wu', 'song', 'production', '-', 'year', 'big', 'get', 'rza'], ['song', 'pop', 'make', 'love', 'sound', '-', 'get', 'album', 'year', 'vocal', 'record', 'single', 'play', 'find', 'come'], ['bowie', 'corgan', 'song', 'root', 'banhart', 'rock', 'pumpkin', 'guitar', 'low', 'harvey', 'make', 'get', 'never', 'snoop', 'album'], ['make', '-', 'blur', 'play', 'song', 'live', 'rock', 'sound', 'year', 'pop', 'record', 'give', 'opeth', 'band', 'love'], ['mile', 'davis', 'jazz', 'set', 'play', 'blue', 'record', 'live', 'disc', 'solo', 'quintet', 'hear', 'brew', 'session', 'kind'], ['pop', 'song', 'make', 'love', '-', 'rock', 'sound', 'go', 'single', 'year', 'album', 'get', 'say', 'come', 'guitar']]
#
#
# [['mccartney', 'lennon', 'bronson', 'tyler', 'kweli', 'song', 'grande', 'love', 'talib', 'mariah', 'woman', 'fetty', 'pop', 'make', 'metal'], ['rap', 'rapper', 'make', 'beat', 'get', 'song', 'hop', 'hip', 'sound', 'track', 'say', '-', 'mixtape', 'year', 'good'], ['banhart', 'song', 'love', 'pop', 'etten', 'sound', 'van', 'make', 'album', 'track', 'year', 'bolan', 'come', 'guitar', 'self'], ['song', 'rock', 'guitar', 'make', 'young', '-', 'sound', 'live', 'album', 'band', 'record', 'year', 'go', 'day', 'love'], ['song', 'rock', 'make', 'band', 'album', '-', 'guitar', 'sound', 'love', 'pop', 'year', 'record', 'track', 'live', 'never'], ['death', 'grip', 'ferry', 'makonnen', 'ride', 'money', 'mc', 'love', 'store', 'hill', 'roxy', 'plate', 'government', 'interview', 'web'], ['song', 'cash', 'make', 'jackson', '-', 'sound', 'record', 'album', 'year', 'track', 'love', 'ween', 'voice', 'man', 'pop'], ['beat', 'make', 'sound', 'song', 'rap', 'track', 'come', 'wu', 'beam', 'year', 'production', 'soul', '-', 'pop', 'rza'], ['song', 'pop', 'make', 'love', 'sound', '-', 'get', 'vocal', 'album', 'rock', 'guitar', 'play', 'voice', 'year', 'track'], ['bowie', 'harvey', 'make', 'play', 'snoop', 'year', 'never', 'common', 'song', 'david', 'moby', 'rock', 'sound', '-', 'album'], ['keef', 'blur', 'song', '-', 'make', 'band', 'pop', 'kanye', 'record', 'rock', 'guitar', 'opeth', 'metal', 'sound', 'year'], ['mile', 'davis', 'jazz', 'set', 'coltrane', 'play', 'live', 'record', 'solo', 'disc', 'session', 'take', 'brew', 'quintet', 'kind'], ['song', 'pop', 'make', 'love', 'rock', 'sound', '-', 'single', 'go', 'get', 'year', 'guitar', 'album', 'track', 'say'], ['pop', 'prince', 'song', 'oberst', 'reznor', 'wait', 'sound', '-', 'love', 'make', 'go', 'rock', 'interpol', 'vocal', 'world']]
#
#
# [['veloso', 'bronson', 'lennon', 'grande', 'swinscoe', 'brazilian', 'dr', 'brazil', 'american', 'velosos', 'piece', 'write', 'cinematic', 'orchestra', 'day'], ['rap', 'rapper', 'beat', 'make', 'get', 'hop', 'hip', 'sound', 'song', 'track', '-', 'come', 'year', 'say', 'mixtape'], ['banhart', 'song', 'love', 'etten', 'van', 'sound', 'pavement', 'album', 'make', 'bolan', 'guitar', 'pop', 'vocal', 'karen', 'come'], ['rock', 'song', 'guitar', '-', 'young', 'make', 'band', 'sound', 'album', 'live', 'year', 'record', 'track', 'vocal', 'go'], ['song', 'rock', 'make', 'album', 'band', 'love', '-', 'guitar', 'live', 'record', 'year', 'pop', 'sound', 'never', 'track'], ['death', 'grip', 'ferry', 'love', 'ride', 'money', 'avett', 'mc', 'store', 'roxy', 'label', 'hill', 'plate', 'government', 'deep'], ['song', 'cash', 'cohen', 'make', 'voice', 'year', 'sound', 'love', 'death', 'album', 'man', 'record', 'life', 'live', '-'], ['sound', 'song', 'make', 'track', 'wu', 'beam', 'pop', 'guitar', 'love', 'voice', 'come', 'record', 'ghost', 'rza', '-'], ['song', 'pop', 'make', 'sound', '-', 'love', 'get', 'year', 'vocal', 'single', 'album', 'guitar', 'record', 'voice', 'come'], ['corgan', 'pumpkin', 'rock', 'song', 'smash', 'moby', 'guitar', 'play', 'national', 'make', 'berninger', 'collie', 'mellon', 'aeroplane', 'dream'], ['keef', 'buckingham', 'nick', 'make', 'song', 'pop', 'band', '-', 'fleetwood', 'kind', 'title', 'dandy', 'love', 'year', 'rumour'], ['mile', 'davis', 'jazz', 'set', 'play', 'record', 'live', 'solo', 'disc', 'session', 'brew', 'quintet', 'take', 'hear', 'kind'], ['pop', 'song', 'rock', 'make', '-', 'love', 'sound', 'go', 'get', 'single', 'year', 'say', 'track', 'album', 'guitar'], ['song', 'wait', 'pop', 'interpol', 'make', 'buckley', 'band', 'rock', 'sound', 'love', '-', 'go', 'turn', 'album', 'key'], ['song', 'rock', 'low', 'guitar', 'sound', 'tengo', 'la', 'record', 'band', 'pop', 'never', 'album', 'make', 'parker', 'vocal']]

# %%
def jaccard_similarity(topic_1, topic_2):
    """
    Derives the Jaccard similarity of two topics

    Jaccard similarity:
    - A statistic used for comparing the similarity and diversity of sample sets
    - J(A,B) = (A ∩ B)/(A ∪ B)
    - Goal is low Jaccard scores for coverage of the diverse elements
    """
    intersection = set(topic_1).intersection(set(topic_2))
    union = set(topic_1).union(set(topic_2))
                    
    return float(len(intersection))/float(len(union))

# %%
LDA_stability = {}
for i in range(0, len(num_topics)-1):
    jaccard_sims = []
    for t1, topic1 in enumerate(LDA_topics[num_topics[i]]): 
        sims = []
        for t2, topic2 in enumerate(LDA_topics[num_topics[i+1]]): 
            sims.append(jaccard_similarity(topic1, topic2))    
        
        jaccard_sims.append(sims)    
    
    LDA_stability[num_topics[i]] = jaccard_sims
                
mean_stabilities = [np.array(LDA_stability[i]).mean() for i in num_topics[:-1]]

# %%
coherences = [gensim.models.CoherenceModel(model=LDA_models[i], texts=pf.tokenized_reviews, dictionary=id2word, coherence='c_v').get_coherence()\
              for i in num_topics[:-1]]

# %%
coh_sta_diffs = [coherences[i] - mean_stabilities[i] for i in range(num_keywords)[:-1]] # limit topic numbers to the number of keywords
coh_sta_max = max(coh_sta_diffs)
coh_sta_max_idxs = [i for i, j in enumerate(coh_sta_diffs) if j == coh_sta_max]
ideal_topic_num_index = coh_sta_max_idxs[0] # choose less topics in case there's more than one max
ideal_topic_num = num_topics[ideal_topic_num_index]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,10))
ax = sns.lineplot(x=num_topics[:-1], y=mean_stabilities, label='Average Topic Overlap')
ax = sns.lineplot(x=num_topics[:-1], y=coherences, label='Topic Coherence')

ax.axvline(x=ideal_topic_num, label='Ideal Number of Topics', color='black')
ax.axvspan(xmin=ideal_topic_num - 1, xmax=ideal_topic_num + 1, alpha=0.5, facecolor='grey')

y_max = max(max(mean_stabilities), max(coherences)) + (0.10 * max(max(mean_stabilities), max(coherences)))
ax.set_ylim([0, y_max])
ax.set_xlim([1, num_topics[-1]-1])
                
ax.axes.set_title('Model Metrics per Number of Topics', fontsize=25)
ax.set_ylabel('Metric Level', fontsize=20)
ax.set_xlabel('Number of Topics', fontsize=20)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Run LDA Topic Model

# %%
pf.build_lda_model(num_topics=14)

# %%
pd.DataFrame(pf.print_lda_topics())
# Out:
#             0        1        2          3           4           5        6  \
# 0          be     have    album       song          do        more     band
# 1          be     have    album       band        more          do    sound
# 2          be     have       do       song       album        band        s
# 3        vile     foal  anselmo  trendkill  philippaki     pantera     kurt
# 4    beatking  houston     cham       thin     gerrard       lizzy       be
# 5          be     have     song          s        more          do    album
# 6       kodak    combo    vibin  weightier         bih        skrt   sloope
# 7          be     have    drake      album        song       sound       do
# 8          be     have     song      album          do        band     more
# 9      womack  ukulele    cooke     vedder       widow  valentinos       be
# 10  armstrong    plant     finn    crowded      string         joc  shifter
# 11     misfit    devil   danzig       rain       movie      horror       be
# 12         be     have        s         do       album         rap     song
# 13         be     song     have      album      beatle          do        s
#
#            7           8          9
# 0      sound           s     record
# 1       make           s       song
# 2       more       sound       make
# 3       holy    southern   hitmaker
# 4     jungle    stripper  freestyle
# 5       make       music     record
# 6       None        None       None
# 7      wayne           s       more
# 8      sound           s     record
# 9    speaker     pickett     terror
# 10     dando    mcalmont        enz
# 11  business  unschooled       None
# 12      make        more        get
# 13     sound        more       band

# %%
pf.update_stopwords(['be', 'have', 'do', 'sound', 'song', 's'])
pf.update_tokenized_corpus()
pf.build_lda_model(num_topics=14)

# %%
pd.DataFrame(pf.print_lda_topics())
# Out:
#      0          1         2       3            4         5      6        7  \
# 0   be       have     album    song           do         s   more      get
# 1   be       have         s      do         song     album  music    sound
# 2   be       have      song   sound           do      more      s    album
# 3   be       have     bowie   album           do         s   song      pop
# 4   be      album      song    have  springsteen         s   more    cohen
# 5   be       have     album    song         more        do      s     band
# 6   be          s      have   album          rap        do   song    track
# 7   be       have         s   jeezy        album        do    rap      bun
# 8   be       cole    albarn  patrol         snow  gorillaz  dexys  rowland
# 9   be       band      have    song        album        do   more     rock
# 10  be       have        do   album         song         s   more     make
# 11  be  morrissey      have    song      jackson     album     do     more
# 12  be      drake      have    song        album     track   make   record
# 13  be     reznor  mastodon   queen         have     homme  album       do
#
#          8       9
# 0    track   sound
# 1     make    when
# 2     make   music
# 3     more    make
# 4       do     pop
# 5     make   sound
# 6     make    more
# 7     doom  boosie
# 8     have    soul
# 9   record   sound
# 10   sound   track
# 11       s    most
# 12    redd    nick
# 13   metal    more
