# %% [markdown]
# # Topic Modeling on Pitchfork Reviews
#
# https://towardsdatascience.com/a-guide-to-collaborative-topic-modeling-recommender-systems-49fd576cc871

# %%
from pprint import pprint
import numpy as np

import json
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import stopwords
import gensim
import gensim.corpora as corpora
import gensim.models.ldamodel as lda
import spacy
import itertools

import pandas as pd
import sqlite3

import re
import unidecode as ud
import pickle
import datetime

from ArtistReviewAnalyzer import ArtistReviewAnalyzer
# Out:
# /Users/celinechoo/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# Initializing analyzer

# %%
pf_file = "../../data/processed/artist_reviews_pf_only.json"
more_sw = ['band', 'make', 'record', 'get', 'even', 'time', 'year', 'good', 'new', 'come', \
                     'go', 'well', 'first', 'take', 'still', 'way', 'much', 'feel', 'work', \
                     'release', 'seem', 'know', 'back', 'thing', 'also', 'album', 'song', 'None']
pf = ArtistReviewAnalyzer()

# %%
t0 = datetime.datetime.now()
pf.build(pf_file, more_stopwords=more_sw, min_df=300, max_df=0.6)
t1 = datetime.datetime.now()
print((t1 - t0).total_seconds())
# Out:
# 131.225737

# %%
print("tf matrix shape:", pf.count_matrix.shape)
print("tfidf matrix shape:", pf.tfidf_matrix.shape)
# Out:
# tf matrix shape: (964211, 548)
# tfidf matrix shape: (964211, 548)

# %% [markdown]
# ## Run LDA Topic Model

# %%
pf.run_and_set_lda_model(num_topics=13)

# %%
pd.DataFrame(pf.print_lda_topics())
# Out:
#             0              1           2            3            4        5  \
# 0       young            rap        rock          say        wayne   rapper
# 1        rock         guitar        love          pop        sonic      say
# 2         pop           love        rock       single       guitar      day
# 3        rock           mile        play          set         live      pop
# 4        rock         guitar       white         love          pop     find
# 5        rock           cash        wait          pop       guitar     live
# 6         pop           love        rock       guitar       single     give
# 7       bowie           rock         pop        smith         love    never
# 8   darnielle             wu       kanye         life         west      rza
# 9        cube         killer     haggard         foal  certificate    black
# 10        rap           beat      rapper          hip          hop      say
# 11        zhu  generationwhy  moneyyyyyy         zhus    moneyyyyy  angelou
# 12     beatle           rock         pop  springsteen         love    never
#
#             6         7          8      9
# 0        show      live        man   None
# 1       lyric      long      vocal   None
# 2       vocal     great        end   None
# 3      single   version       love   None
# 4      mogwai     vocal       give   None
# 5        show     vocal      early   None
# 6        play      long        say   None
# 7      guitar    single  morrissey   None
# 8         man      goat       chip   None
# 9         hit       ice       fuss  death
# 10       love      rock      never   None
# 11  nobleness  giggling      tubbs   None
# 12       live    single       play   None

# %%
lda_13 = []
lda_13.append(pf.lda_model)

# %%
for i in range(3):
    lda_13.append(pf.run_lda_model(num_topics=13))

# %%
def print_lda_topics(model):
    topics = model.print_topics()
    all_topics = []
    for _, s in topics:
        all_topics.append(re.findall(r'(?<=\")[a-z]+(?=\")', s))
    return all_topics

# %%
pd.DataFrame(print_lda_topics(lda_13[1]))
# Out:
#             0              1           2            3            4        5  \
# 0       young            rap        rock          say        wayne   rapper
# 1        rock         guitar        love          pop        sonic      say
# 2         pop           love        rock       single       guitar      day
# 3        rock           mile        play          set         live      pop
# 4        rock         guitar       white         love          pop     find
# 5        rock           cash        wait          pop       guitar     live
# 6         pop           love        rock       guitar       single     give
# 7       bowie           rock         pop        smith         love    never
# 8   darnielle             wu       kanye         life         west      rza
# 9        cube         killer     haggard         foal  certificate    black
# 10        rap           beat      rapper          hip          hop      say
# 11        zhu  generationwhy  moneyyyyyy         zhus    moneyyyyy  angelou
# 12     beatle           rock         pop  springsteen         love    never
#
#             6         7          8      9
# 0        show      live        man   None
# 1       lyric      long      vocal   None
# 2       vocal     great        end   None
# 3      single   version       love   None
# 4      mogwai     vocal       give   None
# 5        show     vocal      early   None
# 6        play      long        say   None
# 7      guitar    single  morrissey   None
# 8         man      goat       chip   None
# 9         hit       ice       fuss  death
# 10       love      rock      never   None
# 11  nobleness  giggling      tubbs   None
# 12       live    single       play   None

# %%
pd.DataFrame(print_lda_topics(lda_13[2]))
# Out:
#             0              1           2            3            4        5  \
# 0       young            rap        rock          say        wayne   rapper
# 1        rock         guitar        love          pop        sonic      say
# 2         pop           love        rock       single       guitar      day
# 3        rock           mile        play          set         live      pop
# 4        rock         guitar       white         love          pop     find
# 5        rock           cash        wait          pop       guitar     live
# 6         pop           love        rock       guitar       single     give
# 7       bowie           rock         pop        smith         love    never
# 8   darnielle             wu       kanye         life         west      rza
# 9        cube         killer     haggard         foal  certificate    black
# 10        rap           beat      rapper          hip          hop      say
# 11        zhu  generationwhy  moneyyyyyy         zhus    moneyyyyy  angelou
# 12     beatle           rock         pop  springsteen         love    never
#
#             6         7          8      9
# 0        show      live        man   None
# 1       lyric      long      vocal   None
# 2       vocal     great        end   None
# 3      single   version       love   None
# 4      mogwai     vocal       give   None
# 5        show     vocal      early   None
# 6        play      long        say   None
# 7      guitar    single  morrissey   None
# 8         man      goat       chip   None
# 9         hit       ice       fuss  death
# 10       love      rock      never   None
# 11  nobleness  giggling      tubbs   None
# 12       live    single       play   None

# %%
pd.DataFrame(print_lda_topics(lda_13[3]))
# Out:
#             0              1           2            3            4        5  \
# 0       young            rap        rock          say        wayne   rapper
# 1        rock         guitar        love          pop        sonic      say
# 2         pop           love        rock       single       guitar      day
# 3        rock           mile        play          set         live      pop
# 4        rock         guitar       white         love          pop     find
# 5        rock           cash        wait          pop       guitar     live
# 6         pop           love        rock       guitar       single     give
# 7       bowie           rock         pop        smith         love    never
# 8   darnielle             wu       kanye         life         west      rza
# 9        cube         killer     haggard         foal  certificate    black
# 10        rap           beat      rapper          hip          hop      say
# 11        zhu  generationwhy  moneyyyyyy         zhus    moneyyyyy  angelou
# 12     beatle           rock         pop  springsteen         love    never
#
#             6         7          8      9
# 0        show      live        man   None
# 1       lyric      long      vocal   None
# 2       vocal     great        end   None
# 3      single   version       love   None
# 4      mogwai     vocal       give   None
# 5        show     vocal      early   None
# 6        play      long        say   None
# 7      guitar    single  morrissey   None
# 8         man      goat       chip   None
# 9         hit       ice       fuss  death
# 10       love      rock      never   None
# 11  nobleness  giggling      tubbs   None
# 12       live    single       play   None

# %%
pf.build(more_stopwords=[], min_df=300, max_df=0.6)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b22ba84a75c2> in <module>
# ----> 1 pf.update_tokenized_corpus()
#       2 pf.build_lda_model(num_topics=14)
#
# ~/Code/cs4300sp2021-ag2496-cc972-mb2359-jjz67-jxl8/scripts/singernlp/ArtistReviewAnalyzer.py in update_tokenized_corpus(self)
#     100     def update_tokenized_corpus(self):
#     101         # Create necessary tokenizer functions, etc.
# --> 102         self.tokenized_reviews = self.tokenize_documents(self.raw_dict)
#     103         self.all_tokens = list(itertools.chain.from_iterable(self.tokenized_reviews))  # Update the all_tokens var
#     104
#
# ~/Code/cs4300sp2021-ag2496-cc972-mb2359-jjz67-jxl8/scripts/singernlp/ArtistReviewAnalyzer.py in tokenize_documents(self, input_dict)
#     141         for a in input_dict:
#     142             reviews_list = input_dict[a]
# --> 143             tokenized_documents.append(self.super_tokenize(" ".join(reviews_list)))
#     144         return tokenized_documents
#     145
#
# ~/Code/cs4300sp2021-ag2496-cc972-mb2359-jjz67-jxl8/scripts/singernlp/ArtistReviewAnalyzer.py in super_tokenize(self, input_string, allowed_postags)
#     151         # Cleaned and lowercase-ized
#     152         cleaned_bunch_of_words = ArtistReviewAnalyzer.clean(input_string)
# --> 153         nlp = self.nlp(cleaned_bunch_of_words)
#     154         return [token.lemma_ for token in nlp
#     155                 if (token.pos_ in allowed_postags and
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     981         DOCS: https://spacy.io/api/language#call
#     982         """
# --> 983         doc = self.make_doc(text)
#     984         if component_cfg is None:
#     985             component_cfg = {}
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/language.py in make_doc(self, text)
#    1063                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1064             )
# -> 1065         return self.tokenizer(text)
#    1066
#    1067     def update(
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._apply_special_cases()
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._prepare_special_spans()
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.Doc.__getitem__()
#
# ~/.pyenv/versions/3.7.6/envs/singerenv/lib/python3.7/site-packages/spacy/util.py in normalize_slice(length, start, stop, step)
#    1075
#    1076
# -> 1077 def normalize_slice(
#    1078     length: int, start: int, stop: int, step: Optional[int] = None
#    1079 ) -> Tuple[int, int]:
#
# KeyboardInterrupt:

# %%
pf.build_lda_model(num_topics=14)

# %%
pd.DataFrame(pf.print_lda_topics())
# Out:
#      0          1         2       3            4         5      6        7  \
# 0   be       have     album    song           do         s   more      get
# 1   be       have         s      do         song     album  music    sound
# 2   be       have      song   sound           do      more      s    album
# 3   be       have     bowie   album           do         s   song      pop
# 4   be      album      song    have  springsteen         s   more    cohen
# 5   be       have     album    song         more        do      s     band
# 6   be          s      have   album          rap        do   song    track
# 7   be       have         s   jeezy        album        do    rap      bun
# 8   be       cole    albarn  patrol         snow  gorillaz  dexys  rowland
# 9   be       band      have    song        album        do   more     rock
# 10  be       have        do   album         song         s   more     make
# 11  be  morrissey      have    song      jackson     album     do     more
# 12  be      drake      have    song        album     track   make   record
# 13  be     reznor  mastodon   queen         have     homme  album       do
#
#          8       9
# 0    track   sound
# 1     make    when
# 2     make   music
# 3     more    make
# 4       do     pop
# 5     make   sound
# 6     make    more
# 7     doom  boosie
# 8     have    soul
# 9   record   sound
# 10   sound   track
# 11       s    most
# 12    redd    nick
# 13   metal    more
